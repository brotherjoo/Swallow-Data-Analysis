# %%
import pandas as pd
import numpy as np

# %%
train_dataf = pd.read_csv("../../data/sample_data/train_first.csv", index_col=0)

train_dataf
# Out:
#                 First  Longitude  Latitude  Longitude_difference  \
# 5    2023-06-11 10:39    128.213    23.906                 1.099
# 12   2023-06-14 20:18    125.896    25.704                -1.276
# 13   2023-06-15 10:54    127.172    27.666                -0.652
# 14   2023-06-15 20:08    127.824    26.644                 1.223
# 16   2023-06-16 20:18    127.503    23.166                 0.598
# ..                ...        ...       ...                   ...
# 565  2024-05-04 10:03    116.608   -27.415                -2.490
# 567   2024-05-05 9:43    128.964    -1.732                 3.135
# 577  2024-05-10 10:24    121.274     6.223                -8.872
# 594  2024-05-18 20:23    127.425    22.678                 0.493
# 595  2024-05-19 10:29    126.932    21.556                 1.492
#
#      Latitude_difference  distance(km)  Latitdue_zlevel  Longitdue_zlevel  \
# 5                 -1.773    413.308996         0.453068          1.204869
# ...

# %%
input = train_dataf[['Longitude_difference', 'Latitude_difference', 'distance(km)']].to_numpy()
target = train_dataf['class'].to_numpy()

# %%
from sklearn.model_selection import train_test_split

train_input, test_input, train_target, test_target = train_test_split(input, target, test_size=0.15)
